# %%
# DESARROLLADOR: Ing. Ramirez Quispe, Robert Marlindo
# LENGUAJE: Python
# PROGRAMA: Peso de muestra

from math import pi

# Datos de entrada
T = 20          # Temperatura en grados Celsius
g = 9.807       # Gravedad m/s^2
P = 0.3         # Porosidad del material
Vt = 1.4137     # Volumen total de material (m^3)
ps = 2650       # Peso específico del sólido (kg/m^3)

# Cálculo de la densidad del agua a temperatura T
pw = round(
    1000. * (1. - (T + 288.941) * (T - 3.986) ** 2 / (508929.2 * (T + 68.13))),
    1
)  # Densidad del agua (kg/m^3)

# Cálculo de volúmenes
Vv = P * Vt        # Volumen de vacíos
Vs = Vt - Vv       # Volumen de sólidos

# Cálculo de pesos
peso_seco_kg = ps * Vs                # Peso seco en kg
peso_seco_N = peso_seco_kg * g         # Peso seco en Newtons
peso_saturado_kg = pw * Vv + ps * Vs   # Peso saturado en kg
peso_saturado_N = peso_saturado_kg * g # Peso saturado en Newtons

# Resultados
print("Densidad del agua pw =", pw, "kg/m^3")
print("Volumen total Vt =", Vt, "m^3")
print("Volumen de vacíos Vv =", Vv, "m^3")
# DESARROLLADOR: Ing. Ramirez Quispe, Robert Marlindo
# LENGUAJE: Python
# PROGRAMA: Peso de muestra

from math import pi

# Datos de entrada
T = 20          # Temperatura en grados Celsius
g = 9.807       # Gravedad m/s^2
P = 0.3         # Porosidad del material
Vt = 1.4137     # Volumen total de material (m^3)
ps = 2650       # Peso específico del sólido (kg/m^3)

# Cálculo de la densidad del agua a temperatura T
pw = round(
    1000. * (1. - (T + 288.941) * (T - 3.986) ** 2 / (508929.2 * (T + 68.13))),
    1
)  # Densidad del agua (kg/m^3)

# Cálculo de volúmenes
Vv = P * Vt        # Volumen de vacíos
Vs = Vt - Vv       # Volumen de sólidos

# Cálculo de pesos
peso_seco_kg = ps * Vs                # Peso seco en kg
peso_seco_N = peso_seco_kg * g         # Peso seco en Newtons
peso_saturado_kg = pw * Vv + ps * Vs   # Peso saturado en kg
peso_saturado_N = peso_saturado_kg * g # Peso saturado en Newtons

# Resultados
print("Densidad del agua pw =", pw, "kg/m^3")
print("Volumen total Vt =", Vt, "m^3")
print("Volumen de vacíos Vv =", Vv, "m^3")
print("Volumen de sólidos Vs =", Vs, "m^3")
print("Peso sólido seco =", peso_seco_N, "N")
print("Peso sólido saturado =", peso_saturado_N, "N")
# Out:
# Densidad del agua pw = 998.2 kg/m^3
# Volumen total Vt = 1.4137 m^3
# Volumen de vacíos Vv = 0.42411 m^3
# Densidad del agua pw = 998.2 kg/m^3
# Volumen total Vt = 1.4137 m^3
# Volumen de vacíos Vv = 0.42411 m^3
# Volumen de sólidos Vs = 0.98959 m^3
# Peso sólido seco = 25718.009194500002 N
# Peso sólido saturado = 29869.769320314004 N
